# %% [markdown]
# <a href="https://colab.research.google.com/github/shaheerzubery/Whisper/blob/main/Whisper_Transcripts_with_Time_stamps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Today we are going to learn how we can use Whisper and it's different model for generating Transcrupts and Time stamps

# %% [markdown]
# We used Python 3.9.9 and PyTorch 1.10.1 to train and test our models, but the codebase is expected to be compatible with Python 3.8-3.11 and recent PyTorch versions. The codebase also depends on a few Python packages, most notably OpenAI's tiktoken for their fast tokenizer implementation. You can download and install (or update to) the latest release of Whisper with the following command

# %% [markdown]
# First we install whisper Openai

# %%
# !pip install -U openai-whisper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.9/792.9 kB 14.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 62.9 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230314-py3-none-any.whl size=796910 sha256=bcf7c9747be7fc1b920f25a84cc3f39da7cca63da31bc9491bfdf24bc24c2a43
#   Stored in directory: /root/.cache/pip/wheels/b2/13/5f/fe8245f6dc59df505879da4b2129932e342f02a80e6b87f27d
# Successfully built openai-whisper
# ...

# %% [markdown]
# Alternatively, the following command will pull and install the latest commit from this repository, along with its Python dependencies:

# %%
# !pip install git+https://github.com/openai/whisper.git
#YOu can use this above command as well if you want
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-kcgq7jig
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-kcgq7jig
#   Resolved https://github.com/openai/whisper.git to commit 248b6cb124225dd263bb9bd32d060b6517e067f8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 22.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tiktoken
#     Found existing installation: tiktoken 0.3.1
#     Uninstalling tiktoken-0.3.1:
#       Successfully uninstalled tiktoken-0.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %% [markdown]
# To update the package to the latest version of this repository, please run:

# %%
# !pip install --upgrade --no-deps --force-reinstall git+https://github.com/openai/whisper.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-f_9lfqwj
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-f_9lfqwj
#   Resolved https://github.com/openai/whisper.git to commit 248b6cb124225dd263bb9bd32d060b6517e067f8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230314-py3-none-any.whl size=798075 sha256=e049a0441dec8d1df521bbcf859420b8eaa1bd656755b97c5127ec0337ea4a67
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1txe8_nh/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...
#   Attempting uninstall: openai-whisper
#     Found existing installation: openai-whisper 20230314
# ...

# %% [markdown]
# Available models and languages
# There are five model sizes, four with English-only versions, offering speed and accuracy tradeoffs. Below are the names of the available models and their approximate memory requirements and relative speed.
#
# Size	Parameters	English-only model	Multilingual model	Required VRAM	Relative speed
# tiny	39 M	tiny.en	tiny	~1 GB	~32x
# base	74 M	base.en	base	~1 GB	~16x
# small	244 M	small.en	small	~2 GB	~6x
# medium	769 M	medium.en	medium	~5 GB	~2x
# large	1550 M	N/A	large	~10 GB	1x
# The .en models for English-only applications tend to perform better, especially for the tiny.en and base.en models. We observed that the difference becomes less significant for the small.en and medium.en models.
#
# Whisper's performance varies widely depending on the language. The figure below shows a WER (Word Error Rate) breakdown by languages of the Fleurs dataset using the large-v2 model (The smaller the numbers, the better the performance). Additional WER scores corresponding to the other models and datasets can be found in Appendix D.1, D.2, and D.4. Meanwhile, more BLEU (Bilingual Evaluation Understudy) scores can be found in Appendix D.3. Both are found in the paper.

# %% [markdown]
# There are 4 model
#
# 1.   Base   -- Parameters 74 Million
# 2.   Tiny   -- 34 Million
# 3. Medium   -- 769 M
# 4. large    -- 1500 M

# %% [markdown]
# Let's use the base model

# %%
import whisper

model = whisper.load_model("base")
result = model.transcribe("/content/66ec45060ea1c0a935d5874c55568a4f.mp3")
print(result["text"])
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 140MiB/s]
# ...

# %% [markdown]
# Let's try tiny

# %%
import whisper

model = whisper.load_model("tiny")
result = model.transcribe("/content/66ec45060ea1c0a935d5874c55568a4f.mp3")
print(result["text"])
# Out:
# 100%|██████████████████████████████████████| 72.1M/72.1M [00:00<00:00, 107MiB/s]
# ...

# %% [markdown]
# Lets try medium

# %%
import whisper

model = whisper.load_model("medium")
result = model.transcribe("/content/66ec45060ea1c0a935d5874c55568a4f.mp3")
print(result["text"])
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:16<00:00, 94.2MiB/s]
# ...

# %% [markdown]
# There are multiple things which we will get from this outptu

# %%
print(result["segments"])

# %% [markdown]
# This is how you can get the time stamps but we will use another methods

# %% [markdown]
# Whisper TIme Stamps

# %%
# !pip3 install --upgrade --no-deps --force-reinstall git+https://github.com/linto-ai/whisper-timestamped
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/linto-ai/whisper-timestamped to /tmp/pip-req-build-2vcabf_q
#   Running command git clone --filter=blob:none --quiet https://github.com/linto-ai/whisper-timestamped /tmp/pip-req-build-2vcabf_q
#   Resolved https://github.com/linto-ai/whisper-timestamped to commit 732865ce9c0c1027c67f964e7200c7db6542b142
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for whisper-timestamped: filename=whisper_timestamped-1.12.20-py3-none-any.whl size=44514 sha256=7880fb5093713ac8d430de5b46361286d1f5acc763583974effd8074c2c3c1f0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ijnqmcx3/wheels/9d/fb/03/ae0b1c8b71edda71e33da77333c78117d879361bdd35de48e4
# Successfully built whisper-timestamped
# ...
#   Attempting uninstall: whisper-timestamped
#     Found existing installation: whisper-timestamped 1.12.20
#     Uninstalling whisper-timestamped-1.12.20:
# ...

# %%
# !pip install openai-whisper==20230124
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 68.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 25.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 41.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.1 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230124-py3-none-any.whl size=1179311 sha256=290bd8b7e0dcd5e80905ce29f5e4a196947ac6a3393c2d75bb7dbf3e153621b6
#   Stored in directory: /root/.cache/pip/wheels/ed/9c/6d/9df9e633b11625901f05fbf6b7bb89aa365705be1f1aa65c7d
# Successfully built openai-whisper
# ...
#   Attempting uninstall: openai-whisper
#     Found existing installation: openai-whisper 20230314
# ...

# %%
# !pip install dtw-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.5/645.5 kB 12.1 MB/s eta 0:00:00
# ...

# %%
import whisper_timestamped as whisper_st

audio = whisper_st.load_audio("/content/66ec45060ea1c0a935d5874c55568a4f.mp3")

model = whisper_st.load_model("tiny")

result = whisper_st.transcribe(model, audio, language="en")

import json
print(json.dumps(result, indent = 2, ensure_ascii = False))
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.
# 100%|██████████| 23104/23104 [00:19<00:00, 1186.84frames/s]
# {
# ...

# %% [markdown]
# This is how you will get the time stamps using whisper
